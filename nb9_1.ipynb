# %%
def add(a, b): # 함수를 정의하고 함수에 매개변수
    return a + b

add2 = add

print(add)
print(add2)

print(add(1, 3))
r1 = add(10, 20)
print(r1 * 100)

r2 = add2("abc", "xyz")
print(r2)

def test():
    return None

r3 = test()
print(r3)
# Out:
# <function add at 0x000001E8A2E9D260>
# <function add at 0x000001E8A2E9D260>
# 4
# 3000
# abcxyz
# None

# %%
if True:
    x = 10

print(x)
# Out:
# 10

# %%
def test(a): # 지역변수 : a(매개변수), x
    x = 100 + a
    print(x)

print(a)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 def test(a): # 지역변수 : a(매개변수), x
#       2     x = 100 + a
#       3     print(x)
#       4
# ----> 5 print(a)
#       6 print(x)
#
# NameError: name 'a' is not defined
